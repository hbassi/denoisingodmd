# %%
import numpy as np
import scipy
import scipy.signal as ss
import matplotlib.pyplot as plt
from scipy.linalg import svd, hankel, eig
from tqdm import trange

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
np.random.seed(999)

# %%
noise = 0.5
overlap = 0.2
Tmax = 1000
dt = 1

# %%
def generate_samples(E, psi0, dt=1, nb=100):
    S = np.zeros(nb, dtype=np.complex128)
    
    for j in trange(nb):
        S[j] = np.sum(np.abs(psi0)**2 * np.exp(-1j * E * j * dt))
    
    return S

# %%
def lam2lamt(lam, lammin, lammax):
    lamt = np.pi / 2 * (lam - (lammin + lammax) / 2) / (lammax - lammin)
    return lamt

# %%
def generate_phi(overlap, N):
    phi = np.zeros((N,1))
    phi[0] = np.sqrt(overlap)
    phi[1:] = np.sqrt((1 - phi[0]**2) / (N - 1))
    return phi

# %%
data_cr2 = scipy.io.loadmat('../../data/Cr2_4000.mat')
psiHF = data_cr2['psiHF']
E = data_cr2['E']

# %%
Et = lam2lamt(E,E[0],E[-1])
# E_center = E - (E.min() + E.max())/2
# Et = E_center / np.abs(E_center).max()

# %%
phi = generate_phi(overlap,len(Et))
print('generated phi')
dataS = generate_samples(Et,phi,dt,Tmax)
# Out:
# generated phi
# 100%|██████████| 1000/1000 [00:00<00:00, 7221.11it/s]

# %%
plt.plot(dataS.real)
plt.xlabel('t')
plt.ylabel('o(t)')
plt.title('True dynamics')
# Out:
# Text(0.5, 1.0, 'True dynamics')

# %%
tdataS = dataS + noise * np.random.randn(Tmax) + 1j * noise * np.random.randn(Tmax)
tdataS = np.clip(tdataS, -1, 1)

# %%
tdataS[0] = 1.0 + 0.0j
plt.plot(tdataS.real)

# %%
errors = []
true = Et[0].item()
for i in trange(2, Tmax + 1):
    f, Pxx_den = ss.welch(tdataS.real[:i], 1, nperseg=None)
    pred = -f[np.argsort(Pxx_den)[-1]] * 2*np.pi
    abs_error = np.abs(pred - true)
    errors.append(np.max([1e-14, abs_error]))
    # plt.plot(f,Pxx_den)
    # plt.show()
# Out:
# 100%|██████████| 999/999 [00:00<00:00, 5894.43it/s]

# %%
plt.semilogy(errors, '*')
plt.xlabel('t')
plt.ylabel('abs error')
# Out:
# Text(0, 0.5, 'abs error')

# %%
errors
# Out:
# [2.356194490192345,
#  1.308996938995747,
#  0.7853981633974483,
#  0.47123889803846897,
#  0.26179938779914935,
#  0.1121997376282069,
#  1e-14,
#  0.08726646259971649,
#  0.15707963267948966,
#  2.0705951580478184,
#  1.8325957145940457,
#  2.114533516839284,
#  1.9073955396795172,
#  1.7278759594743862,
#  1.9634954084936207,
#  1.8017957866176753,
#  1.658062789394613,
#  1.8601535448886932,
#  2.0420352248333655,
#  0.1121997376282069,
#  0.07139983303613162,
#  0.03414774623467165,
#  1e-14,
#  0.031415926535897976,
#  0.0604152433382652,
#  1.437225210570841,
#  1.209937711179853,
#  1.4495603686865657,
#  1.4346606451393389,
#  1.4615687676469071,
#  1.4467860904689838,
#  1.4732632215363899,
#  1.4585965891666897,
#  1.444119203666276,
#  1.4701042545644545,
#  1.455737997125207,
#  1.4415535910459494,
#  1.4670644938933468,
#  1.4529866022852795,
#  1.4781095870150733,
#  1.4641373169507985,
#  1.4503364857830179,
#  1.4750160629659392,
#  1.4613165828061616,
#  1.447782156624212,
#  1.4720336834934211,
#  1.4585965891666892,
#  1.44531851370773,
#  1.4691565644728737,
#  1.4559720339005326,
#  1.4794709589579838,
#  1.4663792299270275,
#  1.4534379805401056,
#  1.4765485471872029,
#  1.4636965772406993,
#  1.4509898272935908,
#  1.473724643678358,
#  1.461103845873465,
#  1.4486232791552935,
#  1.4709943502305798,
#  1.4585965891666897,
#  1.4463343227592356,
#  1.4683530880908813,
#  1.4561706488936474,
#  1.477899769833908,
#  1.4657965723299968,
#  1.4538221322463403,
#  1.4752187725190167,
#  1.4633207886457722,
#  1.4515473909910956,
#  1.4726215563702154,
#  1.4609219723299685,
#  1.449343002558178,
#  1.4701042545644545,
#  1.4585965891666892,
#  1.2239453612335867,
#  1.4676632346315954,
#  1.456341318058585,
#  1.2252211349000195,
#  1.4652950809653884,
#  1.454153035201216,
#  1.4740724150464422,
#  1.4629965788775996,
#  1.4520287996469898,
#  1.471668403259296,
#  1.460764700038732,
#  1e-14,
#  1.469333406164604,
#  1.219237148893182,
#  1.4777396723639198,
#  1.4670644938933468,
#  1.2205013712889925,
#  0.007340169751377967,
#  0.0036530147134765656,
#  1.2217304763960306,
#  0.003619346375103416,
#  1.4627140107310277,
#  1.2229259073905472,
#  1.2137971616142382,
#  1.4606273536486483,
#  1.2240890294392663,
#  1.2150778761081598,
#  1e-14,
#  0.003490658503988664,
#  1.2163245893323316,
#  1.207506427426033,
#  1.2263234481118053,
#  1.217538637581197,
#  0.006829549246934241,
#  0.0033999920493396063,
#  1.218721288030523,
#  0.0033708075682293837,
#  0.006712804815362738,
#  1.2198737431492281,
#  1.2113768282909794,
#  1.070394965305383,
#  1.2209971447775456,
#  1.2126021853291147,
#  1e-14,
#  0.00325891354106822,
#  1.2137971616142382,
#  0.00969627362219072,
#  1.223161074143567,
#  1.214962873174012,
#  0.006385350921930599,
#  0.0031797496493822797,
#  1.2161003820347585,
#  0.0031542094915560925,
#  0.0062831853071796395,
#  1.2172106994486351,
#  1.2092638388817853,
#  1.0772061766755514,
#  1.2182947888921047,
#  1.2104371694713614,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14,
#  1e-14]

# %%
pred = -f[np.argsort(Pxx_den)[-1]] * 2*np.pi

# %%
true = -np.pi/4

# %%
np.abs(pred - true)
# Out:
# 0.0

# %%
Et[0].item() == true
# Out:
# True
