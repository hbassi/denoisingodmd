# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
noisy_dataS = np.load('./data/noisy_dataS_Cr2_noise=0.1_Tmax=1000_overlap=0.2_dt=1.npy')
#noiseless_dataS = np.load('noiseless_dataS_Cr2_noise=0.1_Tmax=1000_overlap=0.2_dt=1.npy')

# %%
plt.plot(np.concatenate([noisy_dataS.real,np.zeros(2*noisy_dataS.shape[0])] ))
plt.plot(noisy_dataS.real)
plt.xlabel('t')
plt.legend(['Original signal', 'Zero-padded signal'])
plt.ylabel('Re[s(t)]')
#plt.plot(noiseless_dataS)
# Out:
# Text(0, 0.5, 'Re[s(t)]')

# %%
.shape
# Out:
# (2000,)

# %%
# Out:
# array([1.        , 1.        , 0.60004357, ..., 0.        , 0.        ,
#        0.        ])

# %%
noisy_dataS.real.shape
# Out:
# (1000,)
